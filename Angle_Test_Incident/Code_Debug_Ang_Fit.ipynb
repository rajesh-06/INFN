// %%
void histbeauty(TH1D* xhist, int col){
 xhist->SetLineWidth(2);
 xhist->SetMarkerStyle(8);
 xhist->SetLineColor(col);   
    
}
//

// %%
void readfillhisto(fstream stream, TH1D * hist, float x , float y , float r)
{
    while(!stream.eof()){
        stream>> x>>y >>r;
//    cout<< x<<"   "<< y << "  "<<rate <<endl;
    hist->Fill(x,r);
    
}
}

// %%
#include "TError.h"
TString filename ="scanx.200mrad.A1.txt";
fstream ch_A1_6_10_2024(filename.Data());
if(!ch_A1_6_10_2024){
    cout<< "ERROR"<< "couldnot find file"<< endl;
}

float x, y,rate;
TH1D* xhist= new TH1D("xhist","",50,-95,-105);

xhist->SetLineWidth(2);
xhist->SetMarkerStyle(8);
xhist->SetLineColor(32);

while(!ch_A1_6_10_2024.eof()){
       //getline(ch_A1_6_10_2024,STRING); // Saves the line in STRING.
	    //    cout<<STRING; // Prints our STRING.
        ch_A1_6_10_2024>> x>>y >>rate;
//    cout<< x<<"   "<< y << "  "<<rate <<endl;
    xhist->Fill(x,rate);
    
}
TCanvas *can = new TCanvas("can ","",1200,1200);
can->cd();
xhist->Draw();
can ->Draw();
gROOT->ProcessLine("gErrorIgnoreLevel = kDebug;");
// Out:
// Warning in <TCanvas::Constructor>: Deleting canvas with same name: can
// input_line_124:2:3: error: use of undeclared identifier 'kDebug'
//  (kDebug)
//   ^
// Error in <HandleInterpreterException>: Error evaluating expression (kDebug)
// Execution of your code was aborted.

// %%
TString filename ="scanx.200mrad.A2.txt";
fstream ch_A2_6_10_2024(filename.Data());
if(!ch_A2_6_10_2024){
    cout<< "ERROR"<< "couldnot find file"<< endl;
}

float x, y,rate;
TH1D* xhist= new TH1D("xhist","",40,-95,-105);

xhist->SetLineWidth(2);
xhist->SetMarkerStyle(8);
xhist->SetLineColor(32);

while(!ch_A2_6_10_2024.eof()){
       //getline(ch_A1_6_10_2024,STRING); // Saves the line in STRING.
	    //    cout<<STRING; // Prints our STRING.
        ch_A2_6_10_2024>> x>>y >>rate;
//    cout<< x<<"   "<< y << "  "<<rate <<endl;
    xhist->Fill(x,rate);
    
}
TCanvas *can = new TCanvas("can ","",1200,1200);
can->cd();
xhist->Draw();
can ->Draw();
// Out:
// Warning in <TFile::Append>: Replacing existing TH1: xhist (Potential memory leak).
// Warning in <TCanvas::Constructor>: Deleting canvas with same name: can

// %%
TString filename ="scanx.200mrad.A3.txt";
fstream ch_A3_6_10_2024(filename.Data());
if(!ch_A2_6_10_2024){
    cout<< "ERROR"<< "couldnot find file"<< endl;
}

float x, y,rate;
TH1D* xhist= new TH1D("xhist","",40,-95,-105);

xhist->SetLineWidth(2);
xhist->SetMarkerStyle(8);
xhist->SetLineColor(32);

while(!ch_A3_6_10_2024.eof()){
       //getline(ch_A1_6_10_2024,STRING); // Saves the line in STRING.
	    //    cout<<STRING; // Prints our STRING.
        ch_A3_6_10_2024>> x>>y >>rate;
//    cout<< x<<"   "<< y << "  "<<rate <<endl;
    xhist->Fill(x,rate);
    
}
TCanvas *can = new TCanvas("can ","",1200,1200);
can->cd();
xhist->Draw();
can ->Draw();
// Out:
// ERRORcouldnot find file
// Warning in <TFile::Append>: Replacing existing TH1: xhist (Potential memory leak).
// Warning in <TCanvas::Constructor>: Deleting canvas with same name: can

// %%
TString filename ="scanx.200mrad.A4.txt";
fstream ch_A4_6_10_2024(filename.Data());
if(!ch_A4_6_10_2024){
    cout<< "ERROR"<< "couldnot find file"<< endl;
}

float x, y,rate;
TH1D* xhist= new TH1D("xhist","",40,-95,-105);

xhist->SetLineWidth(2);
xhist->SetMarkerStyle(8);
xhist->SetLineColor(32);

while(!ch_A4_6_10_2024.eof()){
       //getline(ch_A1_6_10_2024,STRING); // Saves the line in STRING.
	    //    cout<<STRING; // Prints our STRING.
        ch_A4_6_10_2024>> x>>y >>rate;
//    cout<< x<<"   "<< y << "  "<<rate <<endl;
    xhist->Fill(x,rate);
    
}
TCanvas *can = new TCanvas("can ","",1200,1200);
can->cd();
xhist->Draw();
can ->Draw();
// Out:
// Warning in <TFile::Append>: Replacing existing TH1: xhist (Potential memory leak).
// Warning in <TCanvas::Constructor>: Deleting canvas with same name: can

// %%
TString filename1 ="scanx.200mrad.A1.txt";
TString filename2 ="scanx.200mrad.A2.txt";
TString filename3 ="scanx.200mrad.A3.txt";
TString filename4 ="scanx.200mrad.A4.txt";
fstream ch_A1_6_10_2024(filename1.Data());
fstream ch_A2_6_10_2024(filename2.Data());
fstream ch_A3_6_10_2024(filename3.Data());
fstream ch_A4_6_10_2024(filename4.Data());

if(!ch_A1_6_10_2024){
    cout<< "ERROR"<< "couldnot find file"<< endl;
}

if(!ch_A2_6_10_2024){
    cout<< "ERROR"<< "couldnot find file"<< endl;
}

if(!ch_A3_6_10_2024){
    cout<< "ERROR"<< "couldnot find file"<< endl;
}

if(!ch_A4_6_10_2024){
    cout<< "ERROR"<< "couldnot find file"<< endl;
}


float x1, y1,rate1;

float x2, y2,rate2;
float x3, y3,rate3;
float x4, y4,rate4;

TH1D* xhist1= new TH1D("xhist1","",100,-95,-105);
TH1D* xhist2= new TH1D("xhist2","",100,-95,-105);
TH1D* xhist3= new TH1D("xhist3","",100,-95,-105);
TH1D* xhist4= new TH1D("xhist4","",100,-95,-105);
histbeauty(xhist1,12);
histbeauty(xhist2,22);
histbeauty(xhist3,32);
histbeauty(xhist4,42);

while(!ch_A1_6_10_2024.eof()){
       //getline(ch_A1_6_10_2024,STRING); // Saves the line in STRING.
	    //    cout<<STRING; // Prints our STRING.
        ch_A1_6_10_2024>> x1>>y1 >>rate1;
//    cout<< x<<"   "<< y << "  "<<rate <<endl;
    xhist1->Fill(x1,rate1);
    
}

while(!ch_A2_6_10_2024.eof()){
       //getline(ch_A1_6_10_2024,STRING); // Saves the line in STRING.
	    //    cout<<STRING; // Prints our STRING.
        ch_A2_6_10_2024>> x2>>y2 >>rate2;
//    cout<< x<<"   "<< y << "  "<<rate <<endl;
    xhist2->Fill(x2,rate2);
    
}

while(!ch_A3_6_10_2024.eof()){
       //getline(ch_A1_6_10_2024,STRING); // Saves the line in STRING.
	    //    cout<<STRING; // Prints our STRING.
        ch_A3_6_10_2024>> x3>>y3 >>rate3;
//    cout<< x<<"   "<< y << "  "<<rate <<endl;
    xhist3->Fill(x3,rate3);
    
}


while(!ch_A4_6_10_2024.eof()){
       //getline(ch_A1_6_10_2024,STRING); // Saves the line in STRING.
	    //    cout<<STRING; // Prints our STRING.
        ch_A4_6_10_2024>> x4>>y4 >>rate4;
//    cout<< x<<"   "<< y << "  "<<rate <<endl;
    xhist4->Fill(x4,rate4);
    
}


TCanvas *can = new TCanvas("can ","",1200,1200);
can->cd();
xhist1->Draw();
xhist2->Draw("SAME");
xhist3->Draw("SAME");
xhist4->Draw("SAME");

can ->Draw();
// Out:
// Warning in <TCanvas::Constructor>: Deleting canvas with same name: can

// %%
TString filename ="scanx.200mrad.A1.txt";
fstream ch_A1_6_10_2024(filename.Data());

int threshold_val = 1650;
if(!ch_A1_6_10_2024){
    cout<< "ERROR"<< "couldnot find file"<< endl;
}

float x, y,rate;
float xmin = -50;
float xmax =-400;
rate_min = 50;
bool found_min = false;
bool found_max = false;
TH1D* xhist= new TH1D("xhist","",50,-95,-105);

xhist->SetLineWidth(2);
xhist->SetMarkerStyle(8);
xhist->SetLineColor(32);

while(!ch_A1_6_10_2024.eof()){
       //getline(ch_A1_6_10_2024,STRING); // Saves the line in STRING.
	    //    cout<<STRING; // Prints our STRING.
        ch_A1_6_10_2024>> x>>y >>rate;
        //cout<< rate<< endl;
        if(rate>threshold_val){
            cout<< rate<< endl;
            if(x<xmin){
                xmin = x ;
            }
            
            if(x>xmax){
                xmax=x;
            }
            
            
            
        }//end of threshold 
   //cout<< x<<"   "<< xhist->FindBin(x) <<endl;
        
        xhist->Fill(x,rate);
    
}
cout<< xmin <<"   "<< xmax<<endl;
TLine line(xmax,0,xmax,250000);
TLine line2(xmin,0,xmin,250000);
TCanvas *can = new TCanvas("can","",1200,1200);
can->cd();

xhist->Draw();
line.Draw("SAME");
line2.Draw("SAME");
can ->Draw();
// Out:
// 1652.34
// 1758.86
// 1847.59
// 1706.21
// 1783.47
// 1737.29
// 1676.6
// 1757.13
// 1674.14
// 1754.46
// 1709.08
// 1764.38
// 1702.08
// 1656.04
// 1860.38
// 1668.79
// 1895.64
// 1743.05
// 1756.06
// 1733.64
// 1979.35
// 1727.76
// 1766.03
// 1741.56
// 1664.65
// 1749.83
// 1668.95
// 1783.5
// 1773.34
// 1682.59
// 1765.61
// 1785.09
// 1701.4
// 1830.84
// 1795.9
// 1838.98
// 1711.33
// 1746.74
// 1688.9
// 1664
// 1726.72
// 1695.51
// 1763.76
// 1686.61
// 1890.54
// 1845.39
// 1758.89
// 1686.83
// 1779.35
// 1831.24
// 1724.18
// 1884.24
// 1727.5
// 1745.23
// 1835.29
// 1651.98
// 1695.85
// 1685.18
// 1736.52
// 1844.46
// 1923.1
// 2313.76
// 3030.92
// 4636.49
// 10109.3
// 16325.2
// 21367.4
// 23236.4
// 24106.3
// 25834.5
// 26511.9
// 26092.9
// 26871
// 25262.3
// 26678.1
// 26749.1
// 25845.4
// 26068.6
// 26605.2
// 25678.7
// 26561.3
// 26875.7
// 25338.1
// 27356.5
// 27604.8
// 26335.8
// 25535.2
// 26798.8
// 26066.5
// 25740.5
// 25119.3
// 24320.5
// ...

// %%
void beauty(TLine xhist, int col,int width , int style){
 xhist.SetLineWidth(width);
 xhist.SetLineStyle(style);
 xhist.SetLineColor(col);   
    
}
//

// %%
TString filename ="scanx.200mrad.A1.txt";
fstream ch_A1_6_10_2024(filename.Data());

int threshold_val = 10000;
if(!ch_A1_6_10_2024){
    cout<< "ERROR"<< "couldnot find file"<< endl;
}

float x, y,rate;
float xmin = -50;
float xmax =-400;
rate_min = 50;
//error in x 

float xerror = 0.1;
 
bool found_min = false;
bool found_max = false;
int nbin = (120-90)/0.1;
TH1D* xhist= new TH1D("xhist","",100,-95,-105);
TH1D* ratehist= new TH1D("ratehist","",20,0,3000);
gStyle->SetErrorX(xerror);
xhist->SetLineWidth(2);
xhist->SetMarkerStyle(8);
xhist->SetLineColor(32);

while(!ch_A1_6_10_2024.eof()){
       //getline(ch_A1_6_10_2024,STRING); // Saves the line in STRING.
	    //    cout<<STRING; // Prints our STRING.
        ch_A1_6_10_2024>> x>>y >>rate;
        //cout<< rate<< endl;
        if(rate<0.1) continue;
        if(rate>threshold_val){
         //   cout<< rate<< endl;
            if(x<xmin){
                xmin = x ;
            }
            
            if(x>xmax){
                xmax=x;
            }
            
            
            
        }//end of threshold 
   //cout<< x<<"   "<< xhist->FindBin(x) <<endl;
        float rate_error = TMath::Sqrt(rate);
        //xhist->SetErrorX(xerror);
        xhist->Fill(x,rate);
        if(x<-110 || x>-95){
                 ratehist->Fill(rate);
        }
        
    
}



//cout<< xmin <<"   "<< xmax<<endl;
float midval = (xmin+xmax)/2;
TLine line(xmax,0,xmax,90000);
TLine hline(-120,threshold_val,-90,threshold_val);

TLine line2(xmin,0,xmin,90000);

TLine line3(midval,0,midval,90000);
//beauty(line3,33, 12,10);


//xhist->SetBinContent(bin, current_content + rate);
//xhist->SetBinError(bin, sqrt(current_error * current_error + error_in_rate * error_in_rate));

line.SetLineColor(12);
line.SetLineWidth(4);
line.SetLineStyle(10);

line2.SetLineColor(32);
line2.SetLineStyle(10);
line2.SetLineWidth(4);


line3.SetLineColor(44);
line3.SetLineStyle(10);
line3.SetLineWidth(4);


TCanvas *can = new TCanvas("can","",1200,1200);
can->cd();
TF1 * mygaus_bkg =new  TF1("mygaus_bkg","gaus" , 500,2500);
//TF1 * linefunc = new TF1("linefunc", "y-[2]/[2]")
//xhist->Sumw2(0);
//xhist->Draw("HIST");
//line.Draw("SAME");
//line2.Draw("SAME");
//line3.Draw("SAME");
//hline.Draw("SAME");
ratehist->Draw("e");
ratehist->Fit("mygaus_bkg");
can ->Draw();
// Out:
// ****************************************
// Minimizer is Minuit2 / Migrad
// Chi2                      =      2.86622
// NDf                       =            3
// Edm                       =  6.52636e-07
// NCalls                    =           55
// Constant                  =       67.238   +/-   7.17346
// Mean                      =      1671.98   +/-   11.2101
// Sigma                     =      131.882   +/-   9.02099      	 (limited)
// Warning in <TFile::Append>: Replacing existing TH1: xhist (Potential memory leak).
// Warning in <TCanvas::Constructor>: Deleting canvas with same name: can

// %%
float bkg_val = mygaus_bkg->GetParameter(1);
float bkg_err = mygaus_bkg->GetParameter(2);


TString filename ="scanx.200mrad.A1.txt";
fstream ch_A1_6_10_2024(filename.Data());

int threshold_val = bkg_val+3*bkg_err;
if(!ch_A1_6_10_2024){
    cout<< "ERROR"<< "couldnot find file"<< endl;
}

float x, y,rate;
float xmin = -50;
float xmax =-400;
rate_min = 50;
//error in x 

float xerror = 0.1;
 
bool found_min = false;
bool found_max = false;
int nbin = (120-90)/0.1;
TH1D* xhist= new TH1D("xhist","",100,-95,-105);
gStyle->SetErrorX(xerror);
xhist->SetLineWidth(2);
xhist->SetMarkerStyle(8);
xhist->SetLineColor(32);

while(!ch_A1_6_10_2024.eof()){
       //getline(ch_A1_6_10_2024,STRING); // Saves the line in STRING.
	    //    cout<<STRING; // Prints our STRING.
        ch_A1_6_10_2024>> x>>y >>rate;
        //cout<< rate<< endl;
        if(rate<0.1) continue;
        if(rate>threshold_val){
         //   cout<< rate<< endl;
            if(x<xmin){
                xmin = x ;
            }
            
            if(x>xmax){
                xmax=x;
            }
            
            
            
        }//end of threshold 
   //cout<< x<<"   "<< xhist->FindBin(x) <<endl;
        //float rate_error = TMath::Sqrt(rate);
        //xhist->SetErrorX(xerror);
        xhist->Fill(x,rate);
        
    
}



//cout<< xmin <<"   "<< xmax<<endl;
float midval = (xmin+xmax)/2;
TLine line(xmax,0,xmax,90000);
TLine hline(-120,threshold_val,-90,threshold_val);

TLine line2(xmin,0,xmin,90000);

TLine line3(midval,0,midval,90000);
//beauty(line3,33, 12,10);


//xhist->SetBinContent(bin, current_content + rate);
//xhist->SetBinError(bin, sqrt(current_error * current_error + error_in_rate * error_in_rate));

line.SetLineColor(12);
line.SetLineWidth(4);
line.SetLineStyle(10);

line2.SetLineColor(32);
line2.SetLineStyle(10);
line2.SetLineWidth(4);


line3.SetLineColor(44);
line3.SetLineStyle(10);
line3.SetLineWidth(4);


TCanvas *can = new TCanvas("can","",1200,1200);
can->cd();

//TF1 * linefunc = new TF1("linefunc", "y-[2]/[2]")
//xhist->Sumw2(0);
xhist->Draw("HIST");
line.Draw("SAME");
line2.Draw("SAME");
line3.Draw("SAME");
hline.Draw("SAME");
can ->Draw();
// Out:
// Warning in <TFile::Append>: Replacing existing TH1: xhist (Potential memory leak).
// Warning in <TCanvas::Constructor>: Deleting canvas with same name: can

// %%
float bkg_val = mygaus_bkg->GetParameter(1);
float bkg_err = mygaus_bkg->GetParameter(2);

TString filename ="scanx.200mrad.A1.txt";
fstream ch_A1_6_10_2024(filename.Data());

float threshold_val = bkg_val;
if(!ch_A1_6_10_2024){
    cout<< "ERROR"<< "couldnot find file"<< endl;
}

float x, y,rate;
float xmin = -50;
float xmax =-400;
rate_min = 50;
//error in x 
TGraphErrors * xgraph = new TGraphErrors(); 
float xerror = 0.1;
 
bool found_min = false;
bool found_max = false;
int nbin = (120-90)/0.1;

//gStyle->SetErrorX(xerror);
xgraph->SetLineWidth(3);
xgraph->SetMarkerStyle(42);
xgraph->SetLineColor(kRed+2);
int i = 0;
while(!ch_A1_6_10_2024.eof()){
        
       //getline(ch_A1_6_10_2024,STRING); // Saves the line in STRING.
	    //    cout<<STRING; // Prints our STRING.
        ch_A1_6_10_2024>> x>>y >>rate;
        //cout<< rate<< endl;
        //if(rate<0.1) continue;
        if(rate>threshold_val+3*bkg_err){
         //   cout<< rate<< endl;
            if(x<xmin){
                xmin = x ;
            }
            
            if(x>xmax){
                xmax=x;
            }
           
            
            
        }//end of threshold 
   //cout<< x<<"   "<< xhist->FindBin(x) <<endl;
        float rate_error = TMath::Sqrt(rate);
        //xhist->SetErrorX(xerror);
        //xhist->Fill(x,rate);
        xgraph->SetPoint(i,x,rate);
        xgraph->SetPointError(i,xerror,rate_error);
        i++;
    
}



//cout<< xmin <<"   "<< xmax<<endl;
float midval = (xmin+xmax)/2;
TLine line(xmax,0,xmax,40000);
TLine hline(-120,threshold_val,-90,threshold_val);

TLine line2(xmin,0,xmin,40000);

TLine line3(midval,0,midval,40000);
//beauty(line3,33, 12,10);


//xhist->SetBinContent(bin, current_content + rate);
//xhist->SetBinError(bin, sqrt(current_error * current_error + error_in_rate * error_in_rate));

line.SetLineColor(12);
line.SetLineWidth(4);
line.SetLineStyle(10);

line2.SetLineColor(32);
line2.SetLineStyle(10);
line2.SetLineWidth(4);


line3.SetLineColor(44);
line3.SetLineStyle(10);
line3.SetLineWidth(4);


TCanvas *can = new TCanvas("can","",1200,1200);
can->cd();
can->DrawFrame(-120,-2,-90,40000);
xgraph->Draw("Z");
xhist->Sumw2(0);
//xhist->Draw("");
line.Draw("SAME");
line2.Draw("SAME");
line3.Draw("SAME");
hline.Draw("SAME");

can ->Draw();
// Out:
// Warning in <TCanvas::Constructor>: Deleting canvas with same name: can

// %%
// this file is for the second test, we have 10 measurements for each position ,, 
TFile * A1_File = new TFile("scanx.200mrad.A1.txt.tree.root"); // first sipm
TFile * A2_File = new TFile("scanx.200mrad.A2.txt.tree.root"); //second sipm
TFile * A3_File = new TFile("scanx.200mrad.A3.txt.tree.root");// third sipm
TFile * A4_File = new TFile("scanx.200mrad.A4.txt.tree.root");//fourth sipm

// getting treee from each file 
TTree *A1_tree=(TTree*) A1_File->Get("tree");
TTree *A2_tree=(TTree*) A2_File->Get("tree");
TTree *A3_tree=(TTree*) A3_File->Get("tree");
TTree *A4_tree=(TTree*) A4_File->Get("tree");

// each tree have 3 branches x , y and rate 
float x_A1, y_A1, rate_A1;
float x_A2, y_A2, rate_A2;
float x_A3, y_A3, rate_A3;
float x_A4, y_A4, rate_A4;
// defining branches for each file

A1_tree->SetBranchAddress("x", &x_A1);
A1_tree->SetBranchAddress("y", &y_A1);
A1_tree->SetBranchAddress("rate", &rate_A1);

A2_tree->SetBranchAddress("x", &x_A2);
A2_tree->SetBranchAddress("y", &y_A2);
A2_tree->SetBranchAddress("rate", &rate_A2);

A3_tree->SetBranchAddress("x", &x_A3);
A3_tree->SetBranchAddress("y", &y_A3);
A3_tree->SetBranchAddress("rate", &rate_A3);


A4_tree->SetBranchAddress("x", &x_A4);
A4_tree->SetBranchAddress("y", &y_A4);
A4_tree->SetBranchAddress("rate", &rate_A4);



//For A1
//setting some initial x and y limits to set graph frame to make sure the 
float xlim_min_A1 =0;
float xlim_max_A1 =-1000;  

//
float ylim_min_A1=10000000;
float ylim_max_A1  = 0;   
TGraphErrors * RatevsX_A1 = new TGraphErrors();


for (int i = 0 ; i<A1_tree->GetEntries(); i++){
    A1_tree->GetEntry(i);
    if(x_A1<xlim_min_A1) xlim_min_A1 = x_A1;
    if(x_A1> xlim_max_A1) xlim_max_A1 = x_A1;
    
    if(rate_A1<ylim_min_A1) ylim_min_A1 = rate_A1;
    if(rate_A1> ylim_max_A1) ylim_max_A1 = rate_A1;
    
    //cout<< x_A1 <<  "   "<< y_A1 << "  "   << rate_A1 << endl; // just to check the if values are correctly read 
    RatevsX_A1->SetPoint(i , x_A1, rate_A1);
    
    RatevsX_A1->SetPointError(i , 0., 100);
    
    
}// end get Entry A1
RatevsX_A_ALLData = (TGraph*)RatevsX_A1->Clone("RatevsX_A_ALLData");
cout <<  "y limits" << ylim_min_A1 << ylim_max_A1<< endl;
TCanvas * can = new TCanvas("can", "", 600,600);

can->DrawFrame(xlim_min_A1,ylim_min_A1,xlim_max_A1,ylim_max_A1);
//can->DrawFrame(-104.5,ylim_min_A1,-104,ylim_max_A1);
RatevsX_A1->Draw("Z");

can->Draw();
// Out:
// y limits028093.6
// Warning in <TCanvas::Constructor>: Deleting canvas with same name: can

// %%
// bad entries 

vector <float> bad_entry_A1 = {1500,1730};

vector <float> bad_entry_A2 = {1930};

vector <float> bad_entry_A4 = {3910,3820};

// %%
//setting some initial x and y limits to set graph frame to make sure the 
float xlim_min_A1 =0;
float xlim_max_A1 =-1000;  

//
float ylim_min_A1=10000000;
float ylim_max_A1  = 0;   
TGraphErrors * RatevsX_A1 = new TGraphErrors();
cout << "entries are " << A1_tree->GetEntries()<< endl;
for (int i = 0 ; i<A1_tree->GetEntries();i=i+10){
    
    std::vector <float> vrate_A1;
    std:: vector <float> vx_A1;
    for (int j = 0 ; j<10 ; j++){
        A1_tree->GetEntry(i+j);
       // cout << j+i << "i " << i << endl; 
        vrate_A1.push_back(rate_A1);
        vx_A1.push_back(x_A1);
        //cout << " #############"<<rate_A1<< endl;
    
    }
    
    
   // cout << vrate_A1.size()<< endl; // checking if the size is correct should be 10 in my case because we have 10 measurements
   
    
    
    
    float average_rate_A1 = accumulate( vrate_A1.begin(), vrate_A1.end(), 0.0)/vrate_A1.size(); // computing the averate
   // cout << average_rate<< endl; // checking if average is computed correctly

 
    
    float std_dev_rate_A1 = TMath::StdDev(vrate_A1.begin(), vrate_A1.end());
    float err_ave_rate_A1 = std_dev_rate_A1/TMath::Sqrt(vrate_A1.size());
   //  cout << "check calculations "<< "  " << std_dev_rate_A1<< endl; // just to check calculcation if correct
   
    
    
    
   // float av_x_A1 = accumulate( vx_A1.begin(), vx_A1.end(), 0.0)/vx_A1.size(); // computing the averate 
   
   
       
   // cout<< ((i+1)/10)<< endl;
    int graph_entry = (i+1)/10; 
    
    if(std_dev_rate_A1>2000){
            cout << i << "   "<< std_dev_rate_A1<< "   "<<  av_x_A1  << endl;
    }
    
    
    
    //cout << graph_entry<< "    "<<i << endl;
    RatevsX_A1->SetPoint(graph_entry , av_x_A1, average_rate_A1);
    
    RatevsX_A1->SetPointError(graph_entry , 0.05, err_ave_rate_A1);
    
    
}// end get Entry A1

for (int l = 0 ; l<A1_tree->GetEntries();l++){
    A1_tree->GetEntry(l);
    if(x_A1<xlim_min_A1) xlim_min_A1 = x_A1;
    if(x_A1> xlim_max_A1) xlim_max_A1 = x_A1;
    
    if(rate_A1<ylim_min_A1) ylim_min_A1 = rate_A1;
    if(rate_A1> ylim_max_A1) ylim_max_A1 = rate_A1;
}   

//cout <<  "y limits" << ylim_min_A1 << ylim_max_A1<< endl;
TCanvas * can = new TCanvas("can", "", 1200,1200);

can->DrawFrame(xlim_min_A1,ylim_min_A1,xlim_max_A1,ylim_max_A1);

RatevsX_A1->Draw("Z");

can->Draw();
// Out:
// entries are 5010
// input_line_137:2:83: error: use of undeclared identifier 'av_x_A1'
//  (((*(class TGraphErrors **)0x7f0bb4056008))->SetPoint(((*(int*)0x7f0ba1ff9cec)), av_x_A1, ((*(float*)0x7f0ba1ff9cd0))))
//                                                                                   ^
// Error in <HandleInterpreterException>: Error evaluating expression (((*(class TGraphErrors **)0x7f0bb4056008))->SetPoint(((*(int*)0x7f0ba1ff9cec)), av_x_A1, ((*(float*)0x7f0ba1ff9cd0))))
// Execution of your code was aborted.

// %%
//setting some initial x and y limits to set graph frame to make sure the 
float xlim_min_A2 =0;
float xlim_max_A2 =-1000;  

//
float ylim_min_A2=10000000;
float ylim_max_A2  = 0;   
TGraphErrors * RatevsX_A2 = new TGraphErrors();
cout << "entries are " << A2_tree->GetEntries()<< endl;
for (int i = 0 ; i<A2_tree->GetEntries();i=i+10){
    
    std::vector <float> vrate_A2;
    std:: vector <float> vx_A2;
    for (int j = 0 ; j<10 ; j++){
        A2_tree->GetEntry(i+j);
       // cout << j+i << "i " << i << endl; 
        vrate_A2.push_back(rate_A2);
        vx_A2.push_back(x_A2);
        //cout << " #############"<<rate_A2<< endl;
    
    }
    
    
   // cout << vrate_A2.size()<< endl; // checking if the size is correct should be 10 in my case because we have 10 measurements
   
    
    
    
    float average_rate_A2 = accumulate( vrate_A2.begin(), vrate_A2.end(), 0.0)/vrate_A2.size(); // computing the averate
   // cout << average_rate<< endl; // checking if average is computed correctly

 
    
    float std_dev_rate_A2 = TMath::StdDev(vrate_A2.begin(), vrate_A2.end());
    float err_ave_rate_A2 = std_dev_rate_A2/TMath::Sqrt(vrate_A2.size());
   //  cout << "check calculations "<< "  " << std_dev_rate_A2<< endl; // just to check calculcation if correct
   
    
    
    
    float av_x_A2 = accumulate( vx_A2.begin(), vx_A2.end(), 0.0)/vx_A2.size(); // computing the averate 
   
   
       
   // cout<< ((i+1)/10)<< endl;
    int graph_entry = (i+1)/10; 
    
    
    
     if(std_dev_rate_A2>2000){
            cout << i << "   "<< std_dev_rate_A2<< "   "<<  av_x_A2  << endl;
    }
    
    
    //cout << graph_entry<< "    "<<i << endl;
    RatevsX_A2->SetPoint(graph_entry , av_x_A2, average_rate_A2);
    
    RatevsX_A2->SetPointError(graph_entry , 0.05, err_ave_rate_A2);
    
    
}// end get Entry A2

for (int l = 0 ; l<A2_tree->GetEntries();l++){
    A2_tree->GetEntry(l);
    if(x_A2<xlim_min_A2) xlim_min_A2 = x_A2;
    if(x_A2> xlim_max_A2) xlim_max_A2 = x_A2;
    
    if(rate_A2<ylim_min_A2) ylim_min_A2 = rate_A2;
    if(rate_A2> ylim_max_A2) ylim_max_A2 = rate_A2;
}   

//cout <<  "y limits" << ylim_min_A2 << ylim_max_A2<< endl;
TCanvas * can = new TCanvas("can", "", 1200,1200);

can->DrawFrame(xlim_min_A2,ylim_min_A2,xlim_max_A2,ylim_max_A2);

RatevsX_A2->Draw("Z");

can->Draw();
// Out:
// entries are 5010
// 1930   5553.67   -104.65
// Warning in <TCanvas::Constructor>: Deleting canvas with same name: can

// %%
//setting some initial x and y limits to set graph frame to make sure the 
float xlim_min_A3 =0;
float xlim_max_A3 =-1000;  

//
float ylim_min_A3=10000000;
float ylim_max_A3  = 0;   
TGraphErrors * RatevsX_A3 = new TGraphErrors();
cout << "entries are " << A3_tree->GetEntries()<< endl;
for (int i = 0 ; i<A3_tree->GetEntries();i=i+10){
    
    std::vector <float> vrate_A3;
    std:: vector <float> vx_A3;
    for (int j = 0 ; j<10 ; j++){
        A3_tree->GetEntry(i+j);
       // cout << j+i << "i " << i << endl; 
        vrate_A3.push_back(rate_A3);
        vx_A3.push_back(x_A3);
        //cout << " #############"<<rate_A3<< endl;
    
    }
    
    
   // cout << vrate_A3.size()<< endl; // checking if the size is correct should be 10 in my case because we have 10 measurements
   
    
    
    
    float average_rate_A3 = accumulate( vrate_A3.begin(), vrate_A3.end(), 0.0)/vrate_A3.size(); // computing the averate
   // cout << average_rate<< endl; // checking if average is computed correctly

 
    
    float std_dev_rate_A3 = TMath::StdDev(vrate_A3.begin(), vrate_A3.end());
    float err_ave_rate_A3 = std_dev_rate_A3/TMath::Sqrt(vrate_A3.size());
   //  cout << "check calculations "<< "  " << std_dev_rate_A3<< endl; // just to check calculcation if correct
   
    
    
    
    float av_x_A3 = accumulate( vx_A3.begin(), vx_A3.end(), 0.0)/vx_A3.size(); // computing the averate 
   
   
       
   // cout<< ((i+1)/10)<< endl;
    int graph_entry = (i+1)/10; 
    
    
    
     if(std_dev_rate_A3>2000){
            cout << i << "   "<< std_dev_rate_A3<< "   "<<  av_x_A3  << endl;
    }
    
    
    //cout << graph_entry<< "    "<<i << endl;
    RatevsX_A3->SetPoint(graph_entry , av_x_A3, average_rate_A3);
    
    RatevsX_A3->SetPointError(graph_entry , 0.05, err_ave_rate_A3);
    
    
}// end get Entry A3

for (int l = 0 ; l<A3_tree->GetEntries();l++){
    A3_tree->GetEntry(l);
    if(x_A3<xlim_min_A3) xlim_min_A3 = x_A3;
    if(x_A3> xlim_max_A3) xlim_max_A3 = x_A3;
    
    if(rate_A3<ylim_min_A3) ylim_min_A3 = rate_A3;
    if(rate_A3> ylim_max_A3) ylim_max_A3 = rate_A3;
}   

//cout <<  "y limits" << ylim_min_A3 << ylim_max_A3<< endl;
TCanvas * can = new TCanvas("can", "", 1200,1200);

can->DrawFrame(xlim_min_A3,ylim_min_A3,xlim_max_A3,ylim_max_A3);

RatevsX_A3->Draw("Z");

can->Draw();
// Out:
// entries are 5010
// Warning in <TCanvas::Constructor>: Deleting canvas with same name: can

// %%
//setting some initial x and y limits to set graph frame to make sure the 
float xlim_min_A4 =0;
float xlim_max_A4 =-1000;  

//
float ylim_min_A4=10000000;
float ylim_max_A4  = 0;   
TGraphErrors * RatevsX_A4 = new TGraphErrors();
cout << "entries are " << A4_tree->GetEntries()<< endl;
for (int i = 0 ; i<A4_tree->GetEntries();i=i+10){
    
    std::vector <float> vrate_A4;
    std:: vector <float> vx_A4;
    for (int j = 0 ; j<10 ; j++){
        A4_tree->GetEntry(i+j);
       // cout << j+i << "i " << i << endl; 
        vrate_A4.push_back(rate_A4);
        vx_A4.push_back(x_A4);
        //cout << " #############"<<rate_A4<< endl;
    
    }
    
    
   // cout << vrate_A4.size()<< endl; // checking if the size is correct should be 10 in my case because we have 10 measurements
   
    
    
    
    float average_rate_A4 = accumulate( vrate_A4.begin(), vrate_A4.end(), 0.0)/vrate_A4.size(); // computing the averate
   // cout << average_rate<< endl; // checking if average is computed correctly

 
    
    float std_dev_rate_A4 = TMath::StdDev(vrate_A4.begin(), vrate_A4.end());
    float err_ave_rate_A4 = std_dev_rate_A4/TMath::Sqrt(vrate_A4.size());
   //  cout << "check calculations "<< "  " << std_dev_rate_A4<< endl; // just to check calculcation if correct
   
    
    
    
    float av_x_A4 = accumulate( vx_A4.begin(), vx_A4.end(), 0.0)/vx_A4.size(); // computing the averate 
   
   
       
   // cout<< ((i+1)/10)<< endl;
    int graph_entry = (i+1)/10; 
    
    
    
     if(std_dev_rate_A4>2000){
            cout << i << "   "<< std_dev_rate_A4<< "   "<<  av_x_A4  << endl;
    }
    
    
    //cout << graph_entry<< "    "<<i << endl;
    RatevsX_A4->SetPoint(graph_entry , av_x_A4, average_rate_A4);
    
    RatevsX_A4->SetPointError(graph_entry , 0.05, err_ave_rate_A4);
    
    
}// end get Entry A4

for (int l = 0 ; l<A4_tree->GetEntries();l++){
    A4_tree->GetEntry(l);
    if(x_A4<xlim_min_A4) xlim_min_A4 = x_A4;
    if(x_A4> xlim_max_A4) xlim_max_A4 = x_A4;
    
    if(rate_A4<ylim_min_A4) ylim_min_A4 = rate_A4;
    if(rate_A4> ylim_max_A4) ylim_max_A4 = rate_A4;
}   

//cout <<  "y limits" << ylim_min_A4 << ylim_max_A4<< endl;
TCanvas * can = new TCanvas("can", "", 1200,1200);

can->DrawFrame(xlim_min_A4,ylim_min_A4,xlim_max_A4,ylim_max_A4);

RatevsX_A4->Draw("Z");

can->Draw();
// Out:
// entries are 5010
// 3820   8096.3   -114.1
// 3910   3949.18   -114.55
// Warning in <TCanvas::Constructor>: Deleting canvas with same name: can

// %%
for (int l = 1930; l<1940;l++){
    A2_tree->GetEntry(l);
    cout <<"   " <<x_A2<< "   " << rate_A2 << endl;
}
// Out:
//    -104.65   17578.5
//    -104.65   17471.1
//    -104.65   17164.5
//    -104.65   18072.6
//    -104.65   0
//    -104.65   17421.6
//    -104.65   17296.1
//    -104.65   18065.1
//    -104.65   17185.9
//    -104.65   17547

// %%
for (int l = 1730; l<1740;l++){
    A1_tree->GetEntry(l);
    cout <<"   " <<x_A1<< "   " << rate_A1 << endl;
}

//1500   8334.01   -102.5
//1730   7930.56   -103.65

for (int l = 1500; l<1510;l++){
    A1_tree->GetEntry(l);
    cout <<"   " <<x_A1<< "   " << rate_A1 << endl;
}
// Out:
//    -103.65   25384
//    -103.65   25675
//    -103.65   0
//    -103.65   24937.2
//    -103.65   24343.6
//    -103.65   24996.7
//    -103.65   25610.4
//    -103.65   24395.3
//    -103.65   24768.9
//    -103.65   25224
//    -102.5   26569
//    -102.5   26623.5
//    -102.5   26319.3
//    -102.5   26827.4
//    -102.5   25835.9
//    -102.5   26323.6
//    -102.5   26145.5
//    -102.5   26653.5
//    -102.5   25660.4
//    -102.5   0

// %%
// removed bad measurements
TF1 *func =new  TF1("func", "[3]*([0]*[0]* TMath::ACos(1-((x-[1])/[0]))- (([0]-(x-[1]))* TMath::Sqrt(2*[0]*(x-[1])-(x-[1])*(x-[1])))+[2])", -104.5,-104);

TF1 *func =new  TF1("func", "[3]*([0]*[0]* TMath::ACos(1-((x-[1])/[0]))- (([0]-(x-[1]))* TMath::Sqrt(2*[0]*(x-[1])-(x-[1])*(x-[1])))+[2])", -104.5,-104);
func->SetParameters(0.25,-100,2,100);

//setting some initial x and y limits to set graph frame to make sure the 
float xlim_min_A1 =0;
float xlim_max_A1 =-1000;  |

//
float ylim_min_A1=10000000;
float ylim_max_A1  = 0;   
TGraphErrors * RatevsX_A1 = new TGraphErrors();
cout << "entries are " << A1_tree->GetEntries()<< endl;
vector <float> bad_entry_A1 = {1500,1730};
for (int i = 0 ; i<A1_tree->GetEntries();i=i+10){
    
    std::vector <float> vrate_A1;
    std:: vector <float> vx_A1;
    
    bool donotpass =false;
    for(int s = 0; s< bad_entry_A1.size();s++){
        if(i==bad_entry_A1[s] ){
            donotpass = true;
            //cout << i <<  endl;
        }
        
    }
    bool discard = false;
    if(donotpass) continue;
    for (int j = 0 ; j<10 ; j++){
        
        A1_tree->GetEntry(i+j);
       // cout << j+i << "i " << i << endl;
        if(rate_A1<0.1) discard= true;
        vrate_A1.push_back(rate_A1);
        vx_A1.push_back(x_A1);
        //cout << " #############"<<rate_A1<< endl;
    
    }
    
    if(discard) continue;
   // cout << vrate_A1.size()<< endl; // checking if the size is correct should be 10 in my case because we have 10 measurements
   
    
    
    
    float average_rate_A1 = accumulate( vrate_A1.begin(), vrate_A1.end(), 0.0)/vrate_A1.size(); // computing the averate
   // cout << average_rate<< endl; // checking if average is computed correctly

 
    
    float std_dev_rate_A1 = TMath::StdDev(vrate_A1.begin(), vrate_A1.end());
    float err_ave_rate_A1 = std_dev_rate_A1/TMath::Sqrt(vrate_A1.size());
   //  cout << "check calculations "<< "  " << std_dev_rate_A1<< endl; // just to check calculcation if correct
   
    
    
    
    float av_x_A1 = accumulate( vx_A1.begin(), vx_A1.end(), 0.0)/vx_A1.size(); // computing the averate 
   
   
       
   // cout<< ((i+1)/10)<< endl;
    int graph_entry = (i+1)/10; 
    
    if(std_dev_rate_A1>2000){
            cout << i << "   "<< std_dev_rate_A1<< "   "<<  av_x_A1  << endl;
    }
    
    
    
    //cout << graph_entry<< "    "<<i << endl;
    RatevsX_A1->SetPoint(graph_entry , av_x_A1, average_rate_A1);
    
    RatevsX_A1->SetPointError(graph_entry , 0., err_ave_rate_A1);
    
    
}// end get Entry A1

for (int l = 0 ; l<A1_tree->GetEntries();l++){
    A1_tree->GetEntry(l);
    if(x_A1<xlim_min_A1) xlim_min_A1 = x_A1;
    if(x_A1> xlim_max_A1) xlim_max_A1 = x_A1;
    
    if(rate_A1<ylim_min_A1) ylim_min_A1 = rate_A1;
    if(rate_A1> ylim_max_A1) ylim_max_A1 = rate_A1;
}   

//cout <<  "y limits" << ylim_min_A1 << ylim_max_A1<< endl;
TCanvas * can = new TCanvas("can", "", 1200,1200);

//can->DrawFrame(xlim_min_A1,ylim_min_A1,xlim_max_A1,ylim_max_A1);
can->DrawFrame(-105,ylim_min_A1,-100,ylim_max_A1);
RatevsX_A1->Draw("Z");
RatevsX_A1->Fit("func","R");
RatevsX_A1->SetMarkerSize(100);
//RatevsX_A1->SetLineSize(10);
RatevsX_A_ALLData->SetLineColor(kRed-3);
//|RatevsX_A_ALLData->Draw("SAMEZ");
func->Draw("SAME");
can->Draw();

// %%
// this file is for the second test, we have 10 measurements for each position ,, 
TFile * A1_File = new TFile("scanx.200mrad.A1.txt.tree.root"); // first sipm
TFile * A2_File = new TFile("scanx.200mrad.A2.txt.tree.root"); //second sipm
TFile * A3_File = new TFile("scanx.200mrad.A3.txt.tree.root");// third sipm
TFile * A4_File = new TFile("scanx.200mrad.A4.txt.tree.root");//fourth sipm

// getting treee from each file 
TTree *A1_tree=(TTree*) A1_File->Get("tree");
TTree *A2_tree=(TTree*) A2_File->Get("tree");
TTree *A3_tree=(TTree*) A3_File->Get("tree");
TTree *A4_tree=(TTree*) A4_File->Get("tree");

// each tree have 3 branches x , y and rate 
float x_A1, y_A1, rate_A1;
float x_A2, y_A2, rate_A2;
float x_A3, y_A3, rate_A3;
float x_A4, y_A4, rate_A4;
// defining branches for each file

A1_tree->SetBranchAddress("x", &x_A1);
A1_tree->SetBranchAddress("y", &y_A1);
A1_tree->SetBranchAddress("rate", &rate_A1);

A2_tree->SetBranchAddress("x", &x_A2);
A2_tree->SetBranchAddress("y", &y_A2);
A2_tree->SetBranchAddress("rate", &rate_A2);

A3_tree->SetBranchAddress("x", &x_A3);
A3_tree->SetBranchAddress("y", &y_A3);
A3_tree->SetBranchAddress("rate", &rate_A3);


A4_tree->SetBranchAddress("x", &x_A4);
A4_tree->SetBranchAddress("y", &y_A4);
A4_tree->SetBranchAddress("rate", &rate_A4);



//For A1
//setting some initial x and y limits to set graph frame to make sure the 
float xlim_min_A1 =0;
float xlim_max_A1 =-1000;  

//
float ylim_min_A1=10000000;
float ylim_max_A1  = 0;   
TGraphErrors * RatevsX_A1 = new TGraphErrors();


for (int i = 0 ; i<A1_tree->GetEntries(); i++){
    A1_tree->GetEntry(i);
    if(x_A1<xlim_min_A1) xlim_min_A1 = x_A1;
    if(x_A1> xlim_max_A1) xlim_max_A1 = x_A1;
    
    if(rate_A1<ylim_min_A1) ylim_min_A1 = rate_A1;
    if(rate_A1> ylim_max_A1) ylim_max_A1 = rate_A1;
    
    //cout<< x_A1 <<  "   "<< y_A1 << "  "   << rate_A1 << endl; // just to check the if values are correctly read 
    RatevsX_A1->SetPoint(i , x_A1, rate_A1);
    
    RatevsX_A1->SetPointError(i , 0., 100);
    
    
}// end get Entry A1
RatevsX_A_ALLData = (TGraph*)RatevsX_A1->Clone("RatevsX_A_ALLData");
cout <<  "y limits" << ylim_min_A1 << ylim_max_A1<< endl;
TCanvas * can = new TCanvas("can", "", 600,600);

can->DrawFrame(xlim_min_A1,ylim_min_A1,xlim_max_A1,ylim_max_A1);
//can->DrawFrame(-104.5,ylim_min_A1,-104,ylim_max_A1);
RatevsX_A1->Draw("Z");

can->Draw();

// %%
// taking derivative of the data 
    
//setting some initial x and y limits to set graph frame to make sure the 
float xlim_min_A1 =0;
float xlim_max_A1 =-1000;  

//
float ylim_min_A1=10000000;
float ylim_max_A1  = 0;
vector <float> av_rate_A1_ ;
vector <float> av_x_A1_ ;


vector <float> av_rate_A1_err_ ;
vector <float> av_x_A1_err_ ;



TGraphErrors * RatevsX_A1 = new TGraphErrors();
cout << "entries are " << A1_tree->GetEntries()<< endl;
vector <float> bad_entry_A1 = {1500,1730};
for (int i = 0 ; i<A1_tree->GetEntries();i=i+10){
    
    std::vector <float> vrate_A1;
    std:: vector <float> vx_A1;
    
    bool donotpass =false;
    for(int s = 0; s< bad_entry_A1.size();s++){
        if(i==bad_entry_A1[s] ){
            donotpass = true;
            //cout << i <<  endl;
        }
        
    }
    bool discard = false;
    if(donotpass) continue;
    for (int j = 0 ; j<10 ; j++){
        
        A1_tree->GetEntry(i+j);
       // cout << j+i << "i " << i << endl;
        if(rate_A1<0.1) discard= true;
        vrate_A1.push_back(rate_A1);
        vx_A1.push_back(x_A1);
        //cout << " #############"<<rate_A1<< endl;
    
    }
    
    if(discard) continue;
   // cout << vrate_A1.size()<< endl; // checking if the size is correct should be 10 in my case because we have 10 measurements
   
    
    
    
    float average_rate_A1 = accumulate( vrate_A1.begin(), vrate_A1.end(), 0.0)/vrate_A1.size(); // computing the averate
   // cout << average_rate<< endl; // checking if average is computed correctly

 
    
    float std_dev_rate_A1 = TMath::StdDev(vrate_A1.begin(), vrate_A1.end());
    float err_ave_rate_A1 = std_dev_rate_A1/TMath::Sqrt(vrate_A1.size());
   //  cout << "check calculations "<< "  " << std_dev_rate_A1<< endl; // just to check calculcation if correct
   
    
    
    
    float av_x_A1 = accumulate( vx_A1.begin(), vx_A1.end(), 0.0)/vx_A1.size(); // computing the averate 
   
   
       
   // cout<< ((i+1)/10)<< endl;
    int graph_entry = (i+1)/10; 
    
    if(std_dev_rate_A1>2000){
            cout << i << "   "<< std_dev_rate_A1<< "   "<<  av_x_A1  << endl;
    }
    
    
    
    //cout << graph_entry<< "    "<<i << endl;
    
    av_x_A1_.push_back(av_x_A1);
    av_x_A1_err_.push_back(0);
    av_rate_A1_err_.push_back(average_rate_A1);
    av_rate_A1_.push_back(err_ave_rate_A1);
    
    RatevsX_A1->SetPoint(graph_entry , av_x_A1, average_rate_A1);
    
    RatevsX_A1->SetPointError(graph_entry , 0., err_ave_rate_A1);
    
    
}// end get Entry A1

for (int l = 0 ; l<A1_tree->GetEntries();l++){
    A1_tree->GetEntry(l);
    if(x_A1<xlim_min_A1) xlim_min_A1 = x_A1;
    if(x_A1> xlim_max_A1) xlim_max_A1 = x_A1;
    
    if(rate_A1<ylim_min_A1) ylim_min_A1 = rate_A1;
    if(rate_A1> ylim_max_A1) ylim_max_A1 = rate_A1;
}   

//cout <<  "y limits" << ylim_min_A1 << ylim_max_A1<< endl;



TCanvas * can = new TCanvas("can", "", 1200,1200);

//can->DrawFrame(xlim_min_A1,ylim_min_A1,xlim_max_A1,ylim_max_A1);
can->DrawFrame(-120,ylim_min_A1,-95,ylim_max_A1);
TF1 *fermiFunction = new TF1("fermiFunction", [](double *x, double *p) {
        return p[3]+(p[2] / (TMath::Exp((x[0] - p[0]) /p[1]) + 1.0));
}, -103, -99, 4); // Defining the function from 0 to 10, 0 parameters

fermiFunction->SetParameters(-102,0.03,25000,1400);

TF1 *fermiFunction2 = new TF1("fermiFunction2", [](double *x, double *p) {
        return p[3]+(p[2] / (TMath::Exp((p[0]-x[0] ) /p[1]) + 1.0));
}, -105, -103, 4); // Defining the function from 0 to 10, 0 parameters

fermiFunction2->SetParameters(-104,0.03,25000,1400);




TF1 *doublefermiFunction = new TF1("doublefermiFunction", [](double *x, double *p) {
        return p[0]+ p[1]/(TMath::Exp((x[0] - p[2]) /p[4]) + 1.0)/(TMath::Exp((p[3]-x[0] ) /p[5]) + 1.0);
}, -120, -95, 6); // Defining the function from 0 to 10, 0 parameters

doublefermiFunction->SetParameters(1000,25000,-101,-104,0.1,0.1);





TF1 * double_erf = new TF1("double_erf", [](double *x, double *p) {
        return p[0] + p[1] * (TMath::Erf((x[0] - p[2]) /p[4]) + 1.) * (TMath::Erf((p[3]-x[0] ) /p[5]) + 1.) * 0.25;
}, -120, -95, 6); // Defining the function from 0 to 10, 0 parameters


double_erf->SetNpx(1000);
doublefermiFunction->SetNpx(1000);
double_erf->SetParameters(1000,25000,-104,-101,0.1,0.1);
double_erf->SetLineColor(kGreen+3);






RatevsX_A1->Draw("p");


//RatevsX_A1->Fit("fermiFunction","NR");

RatevsX_A1->Fit("doublefermiFunction","NR");

//RatevsX_A1->Fit("fermiFunction2","NR");
RatevsX_A1->Fit("double_erf","NR");
RatevsX_A1->SetMarkerStyle(30);
//RatevsX_A1->SetLineSize(10);
RatevsX_A_ALLData->SetLineColor(kRed-3);
//|RatevsX_A_ALLData->Draw("SAMEZ");
//fermiFunction->Draw("SAME");

//fermiFunction2->Draw("SAME");
double_erf->Draw("SAME");
doublefermiFunction->Draw("SAME");
can->Draw();

// %%
/*av_x_A1_.push_back(av_x_A1);
av_x_A1_err_.push_back(0);
av_rate_A1_err_.push_back(average_rate_A1);
av_rate_A1_.push_back(err_ave_rate_A1);*/
vector <float> drate_dx;
vector <float> dsqrate_dxsq;


TH1D * hddx = new TH1D("hddx","", 100,-1000,30000 ); 
TGraph * graph = new TGraph();
TGraph * graph2 = new TGraph();
vector <float> vdx;
for (int m = 0; m< (av_rate_A1_.size()-1); m++){
   // if (av_x_A1_[m]<-105 ) continue;   
    float dx = av_x_A1_[m+1]-av_x_A1_[m] ;
    //cout << av_x_A1_[m+1]<< " ************" <<av_x_A1_[m]<<"   "<< dx <<endl;
   float drate = av_rate_A1_[m+1]- av_rate_A1_[m];      
    
   float derivative = drate/dx;
   //float second_drivative = derivative/dx
    drate_dx.push_back(derivative);
    vdx.push_back(dx);
    
    //cout<< derivative << endl;
    
    
}


for (int m = 0; m< (drate_dx.size()-1); m++){
    
    float ddxx = av_x_A1_[m+1]-av_x_A1_[m] ;
   float deldrate = drate_dx[m+1]- drate_dx[m];      
    
   float derivative2 = deldrate/ddxx;
   //float second_drivative = derivative/dx
    
    dsqrate_dxsq.push_back(derivative2);
   // cout<< derivative2 << endl;
    //float midval = 0.5* (av_x_A1_[m+1]-av_x_A1_[m]) 
    graph2->SetPoint(m,av_x_A1_[m], drate_dx[m]);
    hddx->Fill(derivative2);
    graph->SetPoint(m,av_x_A1_[m], derivative2);
    
    
}

TCanvas * can = new TCanvas("can","",1800,600);
can->cd();
can->DrawFrame(-120.,-4000,-95,6000);
//hddx->Draw();
graph2->SetMarkerStyle(30);
graph2->Draw("p");

//graph->SetMarkerStyle(20);
//graph->Draw("p");
can->Draw();

// %% [markdown]
// TF1*f1 = new TF1("f1","sin(x)",-3.14,2*3.14);
// TGraph * gr = new TGraph();
// TGraph * gr2 = new TGraph();
// vector <double> dfxdx ;
// vector <double> vfx;
// vector <double> vx;
// TRandom random;
// for (int i =0; i<1000 ; i++){
//
//     double x = -3.14 + 4*3.14 *random.Integer(100)/100;
//
//
//     float r = (float)TMath::Sin(x);
//     //cout << x<< "  "<< r<<endl;
//
//
//     vx.push_back(x);
// }
//
// sort(vx.begin(), vx.end());
// //reverse(vx.begin(), vx.end())
//
// for(int k = 0; k< (vx.size()); k++){
//     float r = (float)TMath::Sin(vx[k]);
//     vfx.push_back(r);
// }
//
//
//
// for(int k = 0; k< (vfx.size()-1); k++){
//
//    float dvfx = vfx[k+1]-vfx[k];
//
//    float dx =     vx[k+1]-vx[k];
//    float newx = 0.5* (vx[k+1]+vx[k]) ;
//   // cout<< vx[k+1] <<"     " <<vx[k] << endl;
//     gr->SetPoint(k,newx,vfx[k]);
//     gr2->SetPoint(k,newx, (dvfx/(dx)));
// }
//
//
// TCanvas * can = new TCanvas("can","",1200,600);
// can->cd();
// can->DrawFrame(-3.14,-1,6.28,1);
// //hddx->Draw();
// gr->SetMarkerStyle(30);
// gr->SetMarkerColor(kRed+2);
// gr->Draw("p");
//
// gr2->SetMarkerStyle(20);
// gr2->SetMarkerColor(kGreen+2);
// gr2->Draw("SAMEp");
//
//
// can->Draw();

// %% [markdown]
// TF1 *fermiFunction = new TF1("fermiFunction", [](double *x, double *p) {
//         return (p[2] / (TMath::Exp(((x[0]+110) - p[0]) /p[1]) + 1.0));
// }, -110, -90, 3); // Defining the function from 0 to 10, 0 parameters
//
// fermiFunction->SetParameters(3,0.06,260000);
// TGraph * gr = new TGraph();
// TGraph * gr2 = new TGraph();
// vector <double> dfxdx ;
// vector <double> vfx;
// vector <double> vx;
// TRandom random;
// for (int i =0; i<1000 ; i++){
//
//     double x = -110+4* ((float)random.Integer(100)/100);
//      //double x = (float)random.Integer(100);
//     //cout<< x << endl;
//
//     float r = fermiFunction->Eval(x);
//     cout << x<< "  "<< r<<endl;
//
//     gr->SetPoint(i,x,r);
//     vx.push_back(x);
// }
//
// TCanvas * can = new TCanvas("can","",1200,600);
// can->cd();
// can->DrawFrame(-110,0,-105,300000);
// //hddx->Draw();
// gr->SetMarkerStyle(30);
// gr->SetMarkerColor(kRed+2);
// gr->Draw("p");
// can->Draw();

// %% [markdown]
// TF1 *fermiFunction = new TF1("fermiFunction", [](double *x, double *p) {
//         return (p[2] / (TMath::Exp(((2-x[0]) - p[0]) /p[1]) + 1.0));
// }, -110, -90, 3); // Defining the function from 0 to 10, 0 parameters
//
// fermiFunction->SetParameters(1.2,0.06,260000);
// TGraph * gr = new TGraph();
// TGraph * gr2 = new TGraph();
// vector <double> dfxdx ;
// vector <double> vfx;
// vector <double> vx;
// TRandom random;
// for (int i =0; i<1000 ; i++){
//
//     double x = 2-2* ((float)random.Integer(100)/100);
//      //double x = (float)random.Integer(100);
//     //cout<< x << endl;
//
//     float r = fermiFunction->Eval(x);
//     cout << x<< "  "<< r<<endl;
//
//     gr->SetPoint(i,x,r);
//     vx.push_back(x);
// }
//
// TCanvas * can = new TCanvas("can","",1200,600);
// can->cd();
// can->DrawFrame(0,0,2,300000);
// //hddx->Draw();
// gr->SetMarkerStyle(30);
// gr->SetMarkerColor(kRed+2);
// gr->Draw("p");
// can->Draw();

// %% [markdown]
// TF1 *fermiFunction = new TF1("fermiFunction", [](double *x, double *p) {
//         return (p[2] / (TMath::Exp(((2-x[0]) - p[0]) /p[1]) + 1.0));
// }, -110, -90, 3); // Defining the function from 0 to 10, 0 parameters
//
// fermiFunction->SetParameters(1.2,0.06,260000);
// TGraph * gr = new TGraph();
// TGraph * gr2 = new TGraph();
// vector <double> dfxdx ;
// vector <double> vfx;
// vector <double> vx;
// TRandom random;
// for (int i =0; i<1000 ; i++){
//
//     double x = 2-2* ((float)random.Integer(100)/100);
//      //double x = (float)random.Integer(100);
//     //cout<< x << endl;
//
//     float r = fermiFunction->Eval(x);
//     cout << x<< "  "<< r<<endl;
//
//     gr->SetPoint(i,x,r);
//     vx.push_back(x);
// }
//
// TCanvas * can = new TCanvas("can","",1200,600);
// can->cd();
// can->DrawFrame(0,0,2,300000);
// //hddx->Draw();
// gr->SetMarkerStyle(30);
// gr->SetMarkerColor(kRed+2);
// gr->Draw("p");
// can->Draw();

// %% [markdown]
// ![image.png](attachment:image.png)
//
// ![image-2.png](attachment:image-2.png)

// %%
// this file is for the second test, we have 10 measurements for each position ,, 
TFile * A1_File = new TFile("scanx.200mrad.A1.txt.tree.root"); // first sipm
TFile * A2_File = new TFile("scanx.200mrad.A2.txt.tree.root"); //second sipm
TFile * A3_File = new TFile("scanx.200mrad.A3.txt.tree.root");// third sipm
TFile * A4_File = new TFile("scanx.200mrad.A4.txt.tree.root");//fourth sipm

// getting treee from each file 
TTree *A1_tree=(TTree*) A1_File->Get("tree");
TTree *A2_tree=(TTree*) A2_File->Get("tree");
TTree *A3_tree=(TTree*) A3_File->Get("tree");
TTree *A4_tree=(TTree*) A4_File->Get("tree");

// each tree have 3 branches x , y and rate 
float x_A1, y_A1, rate_A1;
float x_A2, y_A2, rate_A2;
float x_A3, y_A3, rate_A3;
float x_A4, y_A4, rate_A4;
// defining branches for each file

A1_tree->SetBranchAddress("x", &x_A1);
A1_tree->SetBranchAddress("y", &y_A1);
A1_tree->SetBranchAddress("rate", &rate_A1);

A2_tree->SetBranchAddress("x", &x_A2);
A2_tree->SetBranchAddress("y", &y_A2);
A2_tree->SetBranchAddress("rate", &rate_A2);

A3_tree->SetBranchAddress("x", &x_A3);
A3_tree->SetBranchAddress("y", &y_A3);
A3_tree->SetBranchAddress("rate", &rate_A3);


A4_tree->SetBranchAddress("x", &x_A4);
A4_tree->SetBranchAddress("y", &y_A4);
A4_tree->SetBranchAddress("rate", &rate_A4);



//For A1
//setting some initial x and y limits to set graph frame to make sure the 
float xlim_min_A1 =0;
float xlim_max_A1 =-1000;  

//
float ylim_min_A1=10000000;
float ylim_max_A1  = 0;   
TGraphErrors * RatevsX_A1 = new TGraphErrors(); 

for (int i = 0 ; i<A1_tree->GetEntries(); i++){
    A1_tree->GetEntry(i);
    if(x_A1<xlim_min_A1) xlim_min_A1 = x_A1;
    if(x_A1> xlim_max_A1) xlim_max_A1 = x_A1;
    
    if(rate_A1<ylim_min_A1) ylim_min_A1 = rate_A1;
    if(rate_A1> ylim_max_A1) ylim_max_A1 = rate_A1;
    
    //cout<< x_A1 <<  "   "<< y_A1 << "  "   << rate_A1 << endl; // just to check the if values are correctly read 
    RatevsX_A1->SetPoint(i , x_A1, rate_A1);
    
    RatevsX_A1->SetPointError(i , 0., 100);
    
    
}// end get Entry A1
RatevsX_A_ALLData = (TGraph*)RatevsX_A1->Clone("RatevsX_A_ALLData");
cout <<  "y limits" << ylim_min_A1 << ylim_max_A1<< endl;
TCanvas * can = new TCanvas("can", "", 600,600);

can->DrawFrame(xlim_min_A1,ylim_min_A1,xlim_max_A1,ylim_max_A1);
//can->DrawFrame(-104.5,ylim_min_A1,-104,ylim_max_A1);
RatevsX_A1->Draw("Z");

can->Draw();

// %%
TString filename = "scanx.200mrad.A1.txt.tree.root";

     int n_mes = 10; // number of measurement done for each position.
    // this file is for the second test, we have 10 measurements for each position ,, 
    TFile * File = new TFile(filename.Data()); // first sipm
    
    
    if(!File){
        cout << "can not find the file " << filename.Data()<<endl;
        return;
    }
    // getting treee from each file 
    TTree *tree=(TTree*) File->Get("tree");
    
    if(!tree){
        
        cout<< " can not read tree from file"<< endl;
        return;
              }

    // each tree have 3 branches x , y and rate 
    float x, y, rate;
    vector <float> vavx;
    vector <float> vavrate;
     
    // defining branches for each file
    tree->SetBranchAddress("x", &x);
    tree->SetBranchAddress("y", &y);
    tree->SetBranchAddress("rate", &rate);

    

    //setting some initial x and y limits to set graph frame to make sure the 
    float xlim_min =0.;
    float xlim_max =-1000.;  

    //
    float ylim_min = 10000000.;
    float ylim_max  = 0.;   
    TGraphErrors * RatevsX = new TGraphErrors();

    for (int i = 0 ; i<tree->GetEntries();i=i+n_mes){
        
        
        //bool remove = false;
        
        if(rate<ylim_min) ylim_min = rate;
        if(rate> ylim_max) ylim_max = rate;
    
        std::vector <float> vrate; //vector of rate
        std:: vector <float> vx; // vector of x
        

        for (int j = 0 ; j<n_mes ; j++){

            tree->GetEntry(i+j);

            if(rate<0.1) continue; // flag to remove measruement with zero rate
            vrate.push_back(rate);
            vx.push_back(x);

            
            
       
        }
        
        
        
        
       
        if(x<xlim_min) xlim_min = x;
      
        if(x > xlim_max) xlim_max = x;

        
        float average_rate = accumulate( vrate.begin(), vrate.end(), 0.0)/vrate.size(); // computing the averate
       // cout << average_rate<< endl; // checking if average is computed correctly

        float std_dev_rate = TMath::StdDev(vrate.begin(), vrate.end());
        float err_ave_rate = std_dev_rate/TMath::Sqrt(vrate.size());
        //  cout << "check calculations "<< "  " << std_dev_rate<< endl; // just to check calculcation if correct
   
        float av_x = accumulate( vx.begin(), vx.end(), 0.0)/vx.size(); // computing the averate 
   
        vavx.push_back(av_x);
        vavrate.push_back(average_rate);
       
        int graph_entry = (i+1)/n_mes; // just to fill one value per 



        //cout << graph_entry<< "    "<<i << endl;
        RatevsX->SetPoint(graph_entry , av_x, average_rate);

        RatevsX->SetPointError(graph_entry , 0., err_ave_rate);
        
        

    
    }// end get Entry A1
    
    
    float threshold_val = 10000;
    
        
    float xmin = 1000;
    float xmax = -1000;
    float maxval = -1000;    
    
    
    
    
    //cout<< vavrate.size()<< "#####"<<endl;    
    for(int k=0; k<vavrate.size();k++){
        // cout<< vavrate[k]<< "###########"<< threshold_val << endl;
        if(vavrate[k]>threshold_val){
         //   cout<< rate<< endl;
          //  cout<< vavx[k]<< "###########"<< xmin << endl;
            if(vavx[k]<xmin){
                xmin = vavx[k] ;
            }
            
            if(vavx[k]>xmax){
                xmax=vavx[k];
            }
            if(vavrate[k]>maxval){
                maxval = vavrate[k];
            }
    
    
        }
    }   
        
        
    
    
    
    TCanvas * can = new TCanvas("can", "", 1200,1200);
    can->cd();
    can->DrawFrame(xlim_min,ylim_min,xlim_max,ylim_max);

    RatevsX->Draw("Z");
    
    
    
    can->Draw();
    
    
    can->SaveAs("averagerates_vs_x.png");

// %%
// this file is for the second test, we have 10 measurements for each position ,, 
TFile * A1_Flat_File = new TFile("scanx.flat.A1.txt.tree.root"); // first sipm
TFile * A1_Flat2_File = new TFile("scanx.flat2.A1.txt.tree.root"); // first sipm
TFile * A1_Flat3_File = new TFile("scanx.flat3.A1.txt.tree.root"); // first sipm
TFile * A1_Flat4_File = new TFile("scanx.flat3.A1.txt.tree.root"); // first sipm

// getting treee from each file 
TTree *A1_Flat1_tree=(TTree*) A1_Flat_File->Get("tree");
TTree *A1_Flat2_tree=(TTree*) A1_Flat2_File->Get("tree");
TTree *A1_Flat3_tree=(TTree*) A1_Flat3_File->Get("tree");
TTree *A1_Flat4_tree=(TTree*) A1_Fla
4t4_File->Get("tree");



// each tree have 3 branches x , y and rate 
float x_Flat_A1, y_Flat_A1, rate_Flat_A1;
float x_Flat2_A1, y_Flat2_A1, rate_Flat2_A1;
float x_Flat3_A1, y_Flat3_A1, rate_Flat3_A1;
float x_Flat4_A1, y_Flat4_A1, rate_Flat4_A1;


// defining branches for each file

A1_Flat1_tree->SetBranchAddress("x", &x_Flat_A1);
A1_Flat1_tree->SetBranchAddress("y", &y_Flat_A1);
A1_Flat1_tree->SetBranchAddress("rate", &rate_Flat_A1);




//For A1
//setting some initial x and y limits to set graph frame to make sure the 
float xlim_min_A1 =0;
float xlim_max_A1 =-1000;  

//
float ylim_min_A1=10000000;
float ylim_max_A1  = 0;   
TGraphErrors * RatevsX_A1 = new TGraphErrors(); 

for (int i = 0 ; i<A1_Flat1_tree->GetEntries(); i++){
    A1_Flat1_tree->GetEntry(i);
    if(x_Flat_A1<xlim_min_A1) xlim_min_A1 = x_Flat_A1;
    if(x_Flat_A1> xlim_max_A1) xlim_max_A1 = x_Flat_A1;
    
    if(rate_Flat_A1<ylim_min_A1) ylim_min_A1 = rate_Flat_A1;
    if(rate_Flat_A1> ylim_max_A1) ylim_max_A1 = rate_Flat_A1;
    
    //cout<< x_A1 <<  "   "<< y_A1 << "  "   << rate_A1 << endl; // just to check the if values are correctly read 
    RatevsX_A1->SetPoint(i , x_Flat_A1, rate_Flat_A1);
    
    RatevsX_A1->SetPointError(i , 0., 100);
    
    
}// end get Entry A1
RatevsX_A_ALLData = (TGraph*)RatevsX_A1->Clone("RatevsX_A_ALLData");
cout <<  "y limits" << ylim_min_A1 << ylim_max_A1<< endl;
TCanvas * can = new TCanvas("can", "", 600,600);

can->DrawFrame(xlim_min_A1,ylim_min_A1,xlim_max_A1,ylim_max_A1);
//can->DrawFrame(-104.5,ylim_min_A1,-104,ylim_max_A1);
RatevsX_A1->Draw("Z");

can->Draw();
