// %%
file = TFile::Open("outfile_2.root")
// Out:
// (TFile *) 0x7ff604440bd0

// %%
file->ls();
// Out:
// TNetXNGFile**		root://eoshome-i01.cern.ch//eos/user/a/agautam/SWAN_projects/INFN/Angle_Test_Incident/outfile_2.root
//  TNetXNGFile*		root://eoshome-i01.cern.ch//eos/user/a/agautam/SWAN_projects/INFN/Angle_Test_Incident/outfile_2.root
//   KEY: TGraphErrors	Normalized_rate;1
//   KEY: TGraphErrors	Average_of_all_4_sensors;1
//   KEY: TGraphErrors	Sensor_A1;1
//   KEY: TGraphErrors	Sensor_A2;1
//   KEY: TGraphErrors	Sensor_A3;1
//   KEY: TGraphErrors	Sensor_A4;1

// %%
TCanvas * can = new TCanvas("can","");
TMultiGraph * mg = new TMultiGraph();
mg->Add(Sensor_A1);
mg->Add(Sensor_A2);
mg->Add(Sensor_A3);
mg->Add(Sensor_A4);


mg->Draw("LP");
//TF1 *expf = new TF1("expf","[0]*TMath::Exp([1]*x)-1",0,1000);
//expf->SetLineColor(kBlack);
//graph->Fit("expf");

// %%
c1->SetLogy(0);
c1->Draw();
